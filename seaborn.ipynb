# %% [markdown]
# # Que 1: Name any five plots that we can plot using the Seaborn library. Also, state the uses of each plot.

# %% [markdown]
# 1. scatter plot: it displays the relation between two numric variables, it helps in identifyng pattern, cluster, and outlier in the data .
# #
# 2. line plot : it shows the trend or progression of a numeriacal variable over a continuous intervel. it is commanly used to visualize time series data
# #
# 3. bar plot : it compare categorical data by comparing each categery as bar . it is useful for comparing the quantities of diffrent categeries or displaying frequency counts .
# #
# 4. histogram : it represents the distrubution of a single numerical variable ,it helps in understanding the data central tendancy , spread and skewness.
# #
# 5. box plot : it summerize the distribution of a numerical variable through quartiles , it helps in identifying outliers , comparing distribution and detecting skewness
# #

# %% [markdown]
# # Que 2: Load the "fmri" dataset using the load_dataset function of seaborn. Plot a line plot using x ="timepoint" and y = "signal" for different events and regions.
# # Note: timepoint, signal, event, and region are columns in the fmri dataset.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fmri_data = sns.load_dataset("fmri")
sns.lineplot(data = fmri_data,x="timepoint" , y="signal" , hue='event' ,style="region")
plt.show()

# %% [markdown]
# # Que 3: Load the "titanic" dataset using the load_dataset function of seaborn. Plot two box plots using x ='pclass', y = 'age' and y = 'fare'.
# Note: pclass, age, and fare are columns in the titanic dataset.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
titanic_dataset = sns.load_dataset("titanic")
pd.DataFrame(titanic_dataset)
sns.boxplot(x = 'pclass', y = 'age', data = titanic_dataset)
plt.title("Box plot of age by passanger class ")
plt.show()


sns.boxplot(x = 'pclass', y = 'fare', data = titanic_dataset)
plt.title("Box plot of age by passanger class ")
plt.show()

# %% [markdown]
# # Que 4: Use the "diamonds" dataset from seaborn to plot a histogram for the 'price' column. Use the hue parameter for the 'cut' column of the diamonds dataset.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
diamonds = sns.load_dataset('diamonds')
sns.histplot(x='price', hue='cut' , data=diamonds)
plt.show()

# %% [markdown]
# # Que 5: Use the "iris" dataset from seaborn to plot a pair plot. Use the hue parameter for the "species" column of the iris dataset.

# %%
iris = sns.load_dataset('iris')
sns.pairplot(data= iris, hue='species')
plt.show()

# %% [markdown]
# # Que 6: Use the "flights" dataset from seaborn to plot a heatmap.

# %%
flights_dataset = sns.load_dataset("flights")
flights_matrix = flights_dataset.pivot("month", "year", "passengers")
sns.heatmap(flights_matrix, cmap="YlGnBu")
plt.show()
# Out:
# C:\Users\SHIV\AppData\Local\Temp\ipykernel_6548\339112576.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   flights_matrix = flights_dataset.pivot("month", "year", "passengers")
